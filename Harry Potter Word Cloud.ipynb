# %% [markdown]
# # Imports

# %%
import pdftotext

import re
import matplotlib.pyplot as plt 
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from wordcloud import WordCloud
from PIL import Image
import numpy as np 

from nltk.tokenize import word_tokenize

# %% [markdown]
# # Constants

# %%
FILE_TO_READ = 'DeathlyHallows.pdf'
TEXT_FILE = 'DeathlyHallows.txt'

# %%
import pdftotext
 
# Load your PDF
with open(FILE_TO_READ, "rb") as f:
    pdf = pdftotext.PDF(f)

# Save all text to a txt file.
with open(TEXT_FILE, 'w') as f:
    f.write("\n\n".join(pdf))

# %%
with open(TEXT_FILE, 'r') as file: 
    book = file.read()

# %%
len(book)
# Out:
# 1147896

# %%
sw_nltk = stopwords.words('english')

capital_sw = [each_string.title() for each_string in sw_nltk]
uppercase_sw = [each_string.upper() for each_string in sw_nltk]
add_words = ['Harry', 'Ron', 'Hermione', 'said']

sw_nltk.extend(capital_sw)
sw_nltk.extend(uppercase_sw)


print(sw_nltk)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
words = [word for word in book.split() if word not in (sw_nltk)]
filtered_book = " ".join(words)

filtered_book[:110]
# Out:
# 'Chapter 1 Dark Lord Ascending two men appeared nowhere, yards apart narrow, moonlit lane. second stood quite s'

# %%
filtered_book = re.sub(r'[^\w\s]','',filtered_book)

filtered_book[:110]
# Out:
# 'Chapter 1 Dark Lord Ascending two men appeared nowhere yards apart narrow moonlit lane second stood quite stil'

# %%
words = word_tokenize(filtered_book)

filtered_words = [] 
#Challenge: append non stop words to filtered_words

for word in words: 
        stemmed_word = stemmer.stem(word)
        filtered_words.append(stemmed_word)

ready_to_go =" ".join(filtered_words)

# %%
ready_to_go[:1000]
# Out:
# 'chapter 1 dark lord ascend two men appear nowher yard apart narrow moonlit lane second stood quit still wand direct other chest then recogn stow wand beneath cloak start walk briskli direct new ask taller two the best repli severu snape lane border left wild lowgrow brambl right high nearli manicur hedg men long cloak flap around ankl march thought might late said yaxley blunt featur slide sight branch overhang tress broke moonlight it littl trickier expect hope satisfi confid recept good snape nod elabor turn right wide driveway led lane high hedg curv them run distanc beyond pair impress wroughtiron gate bar men way neither broke step silenc rais left arm kind salut pass straight through though dark metal 7 8 chapter 1 dark lord ascend smoke yew hedg muffl sound men footstep rustl somewher right yaxley drew wand again point companion head sourc nois prove noth purewhit peacock strut majest along top hedg he alway well luciu peacock yaxley thrust wand back cloak snort handsom manor
# ...

# %%
word_cloud = WordCloud().generate(ready_to_go)
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
HP_Icon = 'HPIcon.png'
Broom_Icon = 'snitch.png'

# %%
icon = Image.open(HP_Icon)
image_mask = Image.new(mode = 'RGB', size = icon.size, color=(255,255,255))
image_mask.paste(icon, box = icon) 
rgb_array = np.array(image_mask) #converst the image object to an array 

word_cloud = WordCloud(mask=rgb_array, background_color='white', 
                       max_words = 500)

word_cloud.generate(filtered_book)

plt.figure(figsize=[16,8])
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
icon = Image.open(Broom_Icon)
image_mask = Image.new(mode = 'RGB', size = icon.size, color=(255,255,255))
image_mask.paste(icon, box = icon) 
rgb_array = np.array(image_mask) #converst the image object to an array 

word_cloud = WordCloud(mask=rgb_array, background_color='white', 
                       max_words = 300)

word_cloud.generate(filtered_book)

plt.figure(figsize=[16,8])
plt.imshow(word_cloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
len(filtered_book)
# Out:
# 768032

# %%
# Python3 code to find frequency of each word
# function for calculating the frequency
def freq(str):
  
    # break the string into list of words
    str_list = str.split()
  
    # gives set of unique words
    unique_words = set(str_list)
      
    for words in unique_words :
        print(words , ' : ', str_list.count(words))

# %%
##freq(filtered_book)

# %%
from collections import Counter
  
# split() returns list of all the words in the string
split_it = filtered_book.split()
  
# Pass the split_it list to instance of Counter class.
Counter = Counter(split_it)
  
# most_common() produces k frequently encountered
# input values and their respective counts.
most_occur = Counter.most_common(4)
  
print(most_occur)
# Out:
# [('Harry', 2852), ('said', 1968), ('Hermione', 1100), ('Ron', 1061)]
